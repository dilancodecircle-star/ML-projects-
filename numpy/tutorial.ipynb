# %%
import numpy as np
from time import process_time

# %%
python_lst = [i for i in range(10000)]

# %%
start_time = process_time()

# %%
python_lst = [i+5 for i in python_lst]

# %%
end_time = process_time()

# %%
print(end_time - start_time)
# Out:
# 0.0

# %%
np_array = np.array([i for i in range(10000)])
start_time = process_time()
np_array = np_array+5
end_time =process_time()
print(end_time - start_time)
# Out:
# 0.0

# %%
#np array

# %%
list1 = [1,2,3,4,5]
print(list1)
type(list1)
# Out:
# [1, 2, 3, 4, 5]
# list

# %%
np_array = np.array([1,2,3,4,5])
print(np_array)
type(np_array)
print(np_array.shape)
# Out:
# [1 2 3 4 5]
# (5,)

# %%
#create 1D array

# %%
array= np.array([1,2,3,4,5])

# %%
array.shape
# Out:
# (5,)

# %%
array2 = np.array([[1,2,3,4] , [4,5,6,7]])

# %%
array2.shape
# Out:
# (2, 4)

# %%
print(array2)
# Out:
# [[1 2 3 4]
#  [4 5 6 7]]

# %%
array3= np.array([[[1,2,3] , [3,4,5]],
                  [[1,2,3] , [4,5,6]]])

# %%
array3.shape
# Out:
# (2, 2, 3)

# %%
array2 = np.array([[1,2,3,4] , [4,5,6,7]] , dtype = float)

# %%
print(array2)
# Out:
# [[1. 2. 3. 4.]
#  [4. 5. 6. 7.]]

# %%
x = np.zeros((3,2))

# %%
print(x)
# Out:
# [[0. 0.]
#  [0. 0.]
#  [0. 0.]]

# %%
x = x.T

# %%
print(x)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
y = np.ones((3,3))

# %%
print(y)
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]
#  [1. 1. 1.]]

# %%
z = np.full((4,5) , 8)
print(z)
# Out:
# [[8 8 8 8 8]
#  [8 8 8 8 8]
#  [8 8 8 8 8]
#  [8 8 8 8 8]]

# %%
#create identity metrics

# %%
a = np.eye(3)

# %%
print(a)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
#create nmpy array wit random nbers

# %%
b = np.random.randint(10 ,100,(3,3))
print(b)
# Out:
# [[34 48 89]
#  [28 56 62]
#  [34 25 16]]

# %%
d = np.linspace(10 , 30 , 5)
print(d)
# Out:
# [10. 15. 20. 25. 30.]
