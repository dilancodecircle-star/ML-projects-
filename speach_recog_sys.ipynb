# %%
import speech_recognition 
import pyttsx3

# %%
sr = speech_recognition.Recognizer()
with speech_recognition.Microphone() as source2:
    print(" Silence pleace ")

    sr.adjust_for_ambient_noise(source2 , duration=2)

    print("please speak now ...")

    audio2 = sr.listen(source2)
    textt = sr.recognize_google(audio2)
    textt = textt.lower()
    print("Did you say :- "+textt)
# Out:
#  Silence pleace
# please speak now ...
# ---------------------------------------------------------------------------
# UnknownValueError                         Traceback (most recent call last)
# Cell In[5], line 10
#       6
#       7     print("please speak now ...")
#       8
#       9     audio2 = sr.listen(source2)
# ---> 10     textt = sr.recognize_google(audio2)
#      11     textt = textt.lower()
#      12     print("Did you say :- "+textt)
#      13
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\speech_recognition\recognizers\google.py:263, in recognize_legacy(recognizer, audio_data, key, language, pfilter, show_all, with_confidence, endpoint)
#     256 response_text = obtain_transcription(
#     257     request, timeout=recognizer.operation_timeout
#     258 )
#     260 output_parser = OutputParser(
#     261     show_all=show_all, with_confidence=with_confidence
#     262 )
# --> 263 return output_parser.parse(response_text)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\speech_recognition\recognizers\google.py:134, in OutputParser.parse(self, response_text)
#     133 def parse(self, response_text: str):
# --> 134     actual_result = self.convert_to_result(response_text)
#     135     if self.show_all:
#     136         return actual_result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\speech_recognition\recognizers\google.py:183, in OutputParser.convert_to_result(response_text)
#     181             raise UnknownValueError()
#     182         return result[0]
# --> 183 raise UnknownValueError()
#
# UnknownValueError:
