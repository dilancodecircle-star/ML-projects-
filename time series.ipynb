# %%
import numpy as numpy
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.tsa.api import ExponentialSmoothing , SimpleExpSmoothing,Holt
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings('ignore')

# %%
data_set = pd.read_csv("gold_monthly_csv.csv")

# %%
data_set.head()
# Out:
#       Date  Price
# 0  1950-01  34.73
# 1  1950-02  34.73
# 2  1950-03  34.73
# 3  1950-04  34.73
# 4  1950-05  34.73

# %%
data_set.shape
# Out:
# (847, 2)

# %%
print(f"Date range of gold availab form - {data_set.loc[: , 'Date'][0]} to {data_set.loc[: , 'Date'][len(data_set)-1]}")
# Out:
# Date range of gold availab form - 1950-01 to 2020-07

# %%
print(f"Date range of gold availab form - {data_set['Date'].min()} to {data_set['Date'].max()}")
# Out:
# Date range of gold availab form - 1950-01 to 2020-07

# %%
date= pd.date_range(start='1/1/1950' , end='8/1/2020' , freq='ME')

# %%
date
# Out:
# DatetimeIndex(['1950-01-31', '1950-02-28', '1950-03-31', '1950-04-30',
#                '1950-05-31', '1950-06-30', '1950-07-31', '1950-08-31',
#                '1950-09-30', '1950-10-31',
#                ...
#                '2019-10-31', '2019-11-30', '2019-12-31', '2020-01-31',
#                '2020-02-29', '2020-03-31', '2020-04-30', '2020-05-31',
#                '2020-06-30', '2020-07-31'],
#               dtype='datetime64[us]', length=847, freq='ME')

# %%
data_set['month'] =date

# %%
data_set.drop('Date' , axis=1 ,inplace=True)

# %%
data_set.head()
# Out:
#    Price      month
# 0  34.73 1950-01-31
# 1  34.73 1950-02-28
# 2  34.73 1950-03-31
# 3  34.73 1950-04-30
# 4  34.73 1950-05-31

# %%
data_set = data_set.set_index('month')

# %%
data_set.head()
# Out:
#             Price
# month
# 1950-01-31  34.73
# 1950-02-28  34.73
# 1950-03-31  34.73
# 1950-04-30  34.73
# 1950-05-31  34.73

# %%
data_set.plot(figsize=(20,8))
plt.title("gold price")
plt.xlabel("month")
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
round(data_set.describe() , 3)
# Out:
#           Price
# count   847.000
# mean    416.557
# std     453.665
# min      34.490
# 25%      35.190
# 50%     319.622
# 75%     447.029
# max    1840.807

# %%
data_set.isnull().sum()
# Out:
# Price    0
# dtype: int64
